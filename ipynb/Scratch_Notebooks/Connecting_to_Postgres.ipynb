# %% [markdown]
# Make a library of functions for working with database
#
# Make a library for all your functions doofus

# %% [markdown]
# **To-Do:** Figure how to put pip installs in __init__.py

# %%
! pip install psycopg2
! pip install sqlalchemy

# %%
% run __init__.py

# %%
cd ..
# Out:
# /home/jovyan

# %%
pitches_sample = pd.read_pickle('data/sample_pitchers.p')

# %%
pitcher_data = pd.read_csv('data/savant_data.csv')

# %%
pitches_sample.head(5)
# Out:
#   pitch   mph ev_mph           pitcher        batter  dist spin_rate  \
# 0    FF  97.2   None  Justin Verlander  Rougned Odor  None      2526
# 1    FF  96.5   78.9  Justin Verlander  Rougned Odor   195      2581
# 2    FF  97.0   77.2  Justin Verlander  Rougned Odor   221      2507
# 3    CH  88.2   None  Justin Verlander  Rougned Odor  None      1786
# 4    CH  87.8   None  Justin Verlander  Rougned Odor  None      1762
#
#   launch_angle perceived_vel. zone   game_date count inning     pitch_result  \
# 0         None           None   11  2017-09-27   2-2  Bot 6  swinging_strike
# 1      23.5971           None    1  2017-09-27   2-2  Bot 6             foul
# 2      38.4774           None   11  2017-09-27   2-2  Bot 6             foul
# 3         None           None   14  2017-09-27   1-2  Bot 6             ball
# 4         None           None   13  2017-09-27   0-2  Bot 6             ball
#
#                               ab_result
# 0  Rougned Odor strikes out swinging.
# ...

# %%
import psycopg2 as pg2
from psycopg2.extras import RealDictCursor
from sqlalchemy import create_engine

def connect_to_db(host='postgres', dbname='postgres', user='postgres', password='postgres', port=5432):
    con = pg2.connect(host=host, dbname=dbname, user=user)
    cur = con.cursor(cursor_factory=RealDictCursor)
    
    url = 'postgresql://{}:{}@{}:{}/{}'
    url = url.format(user, password, host, port, dbname)
    engine = create_engine(url)
    
    return con, cur, engine

# %%
con, cur, engine = connect_to_db()
con, cur, engine
# Out:
# (<connection object at 0x7fb7b5858af8; dsn: 'host=postgres dbname=postgres user=postgres', closed: 0>,
#  <cursor object at 0x7fb7b5575548; closed: 0>,
#  Engine(postgresql://postgres:***@postgres:5432/postgres))

# %%
pitches.to_sql('pitchers', engine)

# %%
con.commit()

# %%
cur.close()
con.close()

# %%
print(engine.table_names())
# Out:
# ['pitchers']

# %%
sql = """
SELECT * FROM pitchers 
"""
df = pd.read_sql(sql, con=engine)
df
# Out:
#        index pitch   mph ev_mph           pitcher            batter  dist  \
# 0          0    FF  97.2   None  Justin Verlander      Rougned Odor  None
# 1          1    FF  96.5   78.9  Justin Verlander      Rougned Odor   195
# 2          2    FF  97.0   77.2  Justin Verlander      Rougned Odor   221
# 3          3    CH  88.2   None  Justin Verlander      Rougned Odor  None
# 4          4    CH  87.8   None  Justin Verlander      Rougned Odor  None
# 5          5    FF  94.5   85.7  Justin Verlander      Rougned Odor   211
# 6          6    FF  95.5   80.4  Justin Verlander      Rougned Odor   230
# 7          7    SL  86.3  110.1  Justin Verlander        Joey Gallo   302
# 8          8    FF  96.0   79.3  Justin Verlander        Joey Gallo   237
# 9          9    SL  85.4   52.7  Justin Verlander        Joey Gallo     4
# 10        10    SL  86.4   None  Justin Verlander        Joey Gallo  None
# 11        11    CU  80.4   None  Justin Verlander        Joey Gallo  None
# ...

# %%
df.shape
# Out:
# (49501, 16)

# %%
# cur.execute(
# 'DROP TABLE pitchers;'
# )

# %%
# cur.execute(
# 'CREATE TABLE pitcher_ids (player_id INTEGER PRIMARY KEY, pitcher_name VARCHAR(255));'
# )

# %%
# cur.execute(
# 'CREATE TABLE batter_ids (player_id INTEGER PRIMARY KEY, batter_name VARCHAR(255));'
# )

# %%
# cur.execute(
# 'DROP TABLE batter_ids;'
# )

# %%
mult_loops = list(range(1,10))
mult_loops
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import numpy as np

# %%
len(mult_loops)
# Out:
# 9

# %%
np.sum([mult_loops[0], mult_loops[1], mult_loops[2]])
# Out:
# 6

# %%
sum_list = []
start_counter = 0
while start_counter < len(mult_loops):
    for i in range(0, len(mult_loops), 3):
        end_counter = start_counter + 3
        curr_sel = mult_loops[start_counter:end_counter]
        sum_list.append(np.sum(curr_sel))
        start_counter += 3

sum_list
# Out:
# [6, 15, 24]
